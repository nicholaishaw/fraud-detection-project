# %%
#Importing dependencies
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime

# %% [markdown]
# # Importing Data From SQLite Database

# %% [markdown]
# We needed to retrieve the clean data from the SQLite database ('fraud_detection.db') and load it into a Pandas DataFrame to prepare it for analysis in the neural network model.

# %%
#Creating SQLAlchemy engine and connecting to the SQLite database
engine = create_engine('sqlite:///fraud_detection.db')
connection = engine.connect()

#Creating the pandas dataframe by reading the SQL table
model_df = pd.read_sql_table('CleanFraudDetection', con=connection)

model_df
# Out:
#         transaction_id      time       category  amount   age gender state  \
# 0               119106  07:55:28   shopping_pos    1.07  59.0      F    CT
# 1               179292  14:05:16      kids_pets   94.99  41.0      M    OK
# 2               540729  16:22:29      kids_pets   31.28  69.0      F    MO
# 3               374360  10:44:50  gas_transport   73.06  41.0      M    OK
# 4               314574  01:50:09       misc_net    9.99  52.0      F    IA
# ...                ...       ...            ...     ...   ...    ...   ...
# 111139          444284  12:42:49    food_dining    8.22  24.0      F    IA
# 111140           89444  21:29:49  personal_care  205.69  35.0      F    OH
# 111141          298536  01:05:31       misc_net  277.63  43.0      M    MA
# 111142          301993  04:16:28   shopping_net   13.29  92.0      F    KY
# 111143          354010  23:38:46    food_dining  100.46  39.0      M    WI
#
#         city_pop  is_fraud
# 0           5438         0
# 1           7163         0
# 2            602         0
# 3           7163         0
# 4           2036         0
# ...          ...       ...
# 111139      1583         0
# 111140      7646         0
# 111141     47249         0
# 111142       571         0
# 111143      1360         1
#
# [111144 rows x 9 columns]

# %% [markdown]
# # Dropping and Transforming Columns

# %% [markdown]
# Once the dataset was loaded into a pandas dataframe, certain columns needed to be dropped and transformed for the model to be created. In this case, it was necessary that the column 'time' was transformed into a datetime object and binned so that the model could interpret it. In addition, the transaction id needed to be deleted since it was not a feature or a target. Lastly, we used the pd.get_dummies function to convert the categorical data into numeric.

# %%
#Checking the data types
model_df.dtypes
# Out:
# transaction_id      int64
# time               object
# category           object
# amount            float64
# age               float64
# gender             object
# state              object
# city_pop            int64
# is_fraud            int64
# dtype: object

# %%
#Converting 'time' column to datetime format
#We have to convert the 'time' column to a string first before converting it to a datetime object
model_df['time'] = model_df['time'].astype(str)
model_df['time'] = pd.to_datetime(model_df['time'])

#Defining custom time bins based on hour of the day
#Bins are as follows: early morning (12am-6am), late morning (6am-12pm).\
#afternoon (12pm-4pm), evening (4pm-8pm), night (8pm-12am)
bins = [0, 6, 12, 16, 20, 24]
labels = ['early morning', 'late morning', 'afternoon', 'evening', 'night']

#Extracting hour of the day and categorize into bins
model_df['hour'] = model_df['time'].dt.hour
model_df['time_bins'] = pd.cut(model_df['hour'], bins=bins, labels=labels, right=False)

#Dropping the 'hour' column if not needed
model_df = model_df.drop(columns=['hour', 'time'])

model_df
# Out:
#         transaction_id       category  amount   age gender state  city_pop  \
# 0               119106   shopping_pos    1.07  59.0      F    CT      5438
# 1               179292      kids_pets   94.99  41.0      M    OK      7163
# 2               540729      kids_pets   31.28  69.0      F    MO       602
# 3               374360  gas_transport   73.06  41.0      M    OK      7163
# 4               314574       misc_net    9.99  52.0      F    IA      2036
# ...                ...            ...     ...   ...    ...   ...       ...
# 111139          444284    food_dining    8.22  24.0      F    IA      1583
# 111140           89444  personal_care  205.69  35.0      F    OH      7646
# 111141          298536       misc_net  277.63  43.0      M    MA     47249
# 111142          301993   shopping_net   13.29  92.0      F    KY       571
# 111143          354010    food_dining  100.46  39.0      M    WI      1360
#
#         is_fraud      time_bins
# 0              0   late morning
# 1              0      afternoon
# 2              0        evening
# 3              0   late morning
# 4              0  early morning
# ...          ...            ...
# 111139         0      afternoon
# 111140         0          night
# 111141         0  early morning
# 111142         0  early morning
# 111143         1          night
#
# [111144 rows x 9 columns]

# %%
#Dropping the transaction_id since it's not a feature for the model
model_df.drop(columns='transaction_id', inplace=True)
model_df
# Out:
#              category  amount   age gender state  city_pop  is_fraud  \
# 0        shopping_pos    1.07  59.0      F    CT      5438         0
# 1           kids_pets   94.99  41.0      M    OK      7163         0
# 2           kids_pets   31.28  69.0      F    MO       602         0
# 3       gas_transport   73.06  41.0      M    OK      7163         0
# 4            misc_net    9.99  52.0      F    IA      2036         0
# ...               ...     ...   ...    ...   ...       ...       ...
# 111139    food_dining    8.22  24.0      F    IA      1583         0
# 111140  personal_care  205.69  35.0      F    OH      7646         0
# 111141       misc_net  277.63  43.0      M    MA     47249         0
# 111142   shopping_net   13.29  92.0      F    KY       571         0
# 111143    food_dining  100.46  39.0      M    WI      1360         1
#
#             time_bins
# 0        late morning
# 1           afternoon
# 2             evening
# 3        late morning
# 4       early morning
# ...               ...
# 111139      afternoon
# 111140          night
# 111141  early morning
# 111142  early morning
# 111143          night
#
# [111144 rows x 8 columns]

# %%
#Transforming the categorical data into numeric
categorical_df = pd.get_dummies(model_df)
categorical_df.shape
# Out:
# (111144, 75)

# %% [markdown]
# # Separating the Lables and the Features

# %%
#Separating the labels and the features 
X = categorical_df.drop(["is_fraud"], axis='columns').values
y = categorical_df["is_fraud"].values

# %%
#Reviewing the series of lables
y
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
#Reviewing the features
X
# Out:
# array([[1.0700e+00, 5.9000e+01, 5.4380e+03, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [9.4990e+01, 4.1000e+01, 7.1630e+03, ..., 1.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [3.1280e+01, 6.9000e+01, 6.0200e+02, ..., 0.0000e+00, 1.0000e+00,
#         0.0000e+00],
#        ...,
#        [2.7763e+02, 4.3000e+01, 4.7249e+04, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [1.3290e+01, 9.2000e+01, 5.7100e+02, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [1.0046e+02, 3.9000e+01, 1.3600e+03, ..., 0.0000e+00, 0.0000e+00,
#         1.0000e+00]])

# %% [markdown]
# # Split the Data

# %%
#Importing dependencies 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
#Splitting the data into training and testing sets. Random state of 1 will be assigned.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
#Creating a StandardScaler instance
scaler = StandardScaler()

#Fitting the StandardScaler
X_scaler = scaler.fit(X_train)

#Scaling the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile and Train the Model

# %% [markdown]
# Using the training and testing data, we created a neural network model with three layers. We created our model using 80 nodes in the first layer and 30 nodes in the second. We used 100 epochs for optimal model performance.

# %%
#Importing dependencies 
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, balanced_accuracy_score

# %%
#Defining the model - deep neural net
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30
nn = tf.keras.models.Sequential()

#First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

#Second hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer2, input_dim=number_input_features, activation="relu")
)

#Output layer
nn.add(
    tf.keras.layers.Dense(units=1, activation="sigmoid")
)

#Checking the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 80)                6000
#
#  dense_4 (Dense)             (None, 30)                2430
#
#  dense_5 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 8461 (33.05 KB)
# Trainable params: 8461 (33.05 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Compiling the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#Training the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 2779/2779 [==============================] - 7s 2ms/step - loss: 0.0251 - accuracy: 0.9925
# Epoch 2/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0126 - accuracy: 0.9971
# Epoch 3/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0107 - accuracy: 0.9974
# Epoch 4/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0095 - accuracy: 0.9978
# Epoch 5/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0084 - accuracy: 0.9981
# Epoch 6/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0075 - accuracy: 0.9982
# Epoch 7/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0068 - accuracy: 0.9985
# Epoch 8/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0064 - accuracy: 0.9985
# Epoch 9/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0058 - accuracy: 0.9986
# Epoch 10/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0055 - accuracy: 0.9988
# Epoch 11/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0053 - accuracy: 0.9987
# Epoch 12/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0050 - accuracy: 0.9988
# Epoch 13/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0047 - accuracy: 0.9989
# Epoch 14/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0046 - accuracy: 0.9989
# Epoch 15/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0044 - accuracy: 0.9989
# Epoch 16/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0041 - accuracy: 0.9990
# Epoch 17/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0040 - accuracy: 0.9989
# Epoch 18/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0038 - accuracy: 0.9990
# Epoch 19/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0037 - accuracy: 0.9989
# Epoch 20/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0037 - accuracy: 0.9989
# Epoch 21/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 22/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0033 - accuracy: 0.9991
# Epoch 23/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 24/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 25/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 26/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0031 - accuracy: 0.9991
# Epoch 27/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0029 - accuracy: 0.9991
# Epoch 28/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0030 - accuracy: 0.9991
# Epoch 29/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 30/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0027 - accuracy: 0.9992
# Epoch 31/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 32/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 33/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 34/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 35/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 36/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 37/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 38/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 39/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 40/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 41/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 42/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 43/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 44/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 45/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 46/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 47/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 48/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 49/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 50/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 51/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 52/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 53/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 54/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 55/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0019 - accuracy: 0.9993
# Epoch 56/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0023 - accuracy: 0.9994
# Epoch 57/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 58/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 59/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 60/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 61/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 62/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 63/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 64/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0017 - accuracy: 0.9994
# Epoch 65/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0017 - accuracy: 0.9994
# Epoch 66/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0023 - accuracy: 0.9994
# Epoch 67/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 68/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 69/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 70/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 71/100
# 2779/2779 [==============================] - 9s 3ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 72/100
# 2779/2779 [==============================] - 9s 3ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 73/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 74/100
# 2779/2779 [==============================] - 7s 2ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 75/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 76/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 77/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 78/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 79/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 80/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 81/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 82/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 83/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 84/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 85/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 86/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0017 - accuracy: 0.9994
# Epoch 87/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 88/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 89/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 90/100
# 2779/2779 [==============================] - 7s 3ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 91/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 92/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0017 - accuracy: 0.9994
# Epoch 93/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0026 - accuracy: 0.9995
# Epoch 94/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 95/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 96/100
# 2779/2779 [==============================] - 5s 2ms/step - loss: 0.0023 - accuracy: 0.9994
# Epoch 97/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0021 - accuracy: 0.9995
# Epoch 98/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 99/100
# 2779/2779 [==============================] - 6s 2ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 100/100
# 2779/2779 [==============================] - 8s 3ms/step - loss: 0.0015 - accuracy: 0.9995

# %%
#Making a prediction with the model
prediction = nn.predict(X_test)
prediction
# Out:
# 695/695 [==============================] - 1s 1ms/step
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# The model achieved 99.7% accuracy, signifying that it was able to correctly identify instances of fraud 99.7% of the time.

# %%
#Evaluating the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 695/695 - 1s - loss: 0.0356 - accuracy: 0.9982 - 802ms/epoch - 1ms/step
# Loss: 0.03560638800263405, Accuracy: 0.998200535774231

# %%
#Calculating other metrics of model performance

#This converts the continuous outcomes to binary (anything below a 0.5 is not fraud, and anything above a 0.5 is fraud)
threshold = 0.5
predicted_labels = (prediction > threshold).astype(int)

#Calculating Balanced Accuracy Score
#The Balanced accuracy is low since there are substantially more 0s than 1s 
balanced_acc = balanced_accuracy_score(y_test, predicted_labels)
print("Balanced Accuracy Score:", balanced_acc)
# Out:
# Balanced Accuracy Score: 0.49496977352702337

# %%
#Calculating confusion matrix
conf_matrix = confusion_matrix(y_test, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[21943   223]
#  [   63     0]]

# %%
#Generating classification report
class_report = classification_report(y_test, predicted_labels)
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     22166
#            1       0.00      0.00      0.00        63
#
#     accuracy                           0.99     22229
#    macro avg       0.50      0.49      0.50     22229
# weighted avg       0.99      0.99      0.99     22229
